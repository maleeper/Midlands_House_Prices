# %%
import zipfile
from pathlib import Path
import pandas as pd

zip_dir = Path("../data/raw/EPC")
frames = []

for zip_path in zip_dir.glob("*.zip"):
    with zipfile.ZipFile(zip_path) as zf:
        # find the certificates file regardless of case
        names = zf.namelist()
        cert_name = next((n for n in names if n.lower() == "certificates.csv"), None)
        if cert_name is None:
            continue  # skip unexpected bundles

        with zf.open(cert_name) as fh:
            frames.append(pd.read_csv(fh, sep=",", low_memory=False))

epc_master = pd.concat(frames, ignore_index=True)
epc_master.to_csv("../data/clean/epc_master.csv", index=False)
# check the result
epc_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3343753 entries, 0 to 3343752
# Data columns (total 93 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   LMK_KEY                        object
#  1   ADDRESS1                       object
#  2   ADDRESS2                       object
#  3   ADDRESS3                       object
#  4   POSTCODE                       object
#  5   BUILDING_REFERENCE_NUMBER      int64
#  6   CURRENT_ENERGY_RATING          object
#  7   POTENTIAL_ENERGY_RATING        object
#  8   CURRENT_ENERGY_EFFICIENCY      int64
#  9   POTENTIAL_ENERGY_EFFICIENCY    int64
#  10  PROPERTY_TYPE                  object
#  11  BUILT_FORM                     object
#  12  INSPECTION_DATE                object
#  13  LOCAL_AUTHORITY                object
#  14  CONSTITUENCY                   object
#  15  COUNTY                         object
#  16  LODGEMENT_DATE                 object
#  17  TRANSACTION_TYPE               object
#  18  ENVIRONMENT_IMPACT_CURRENT     int64
#  19  ENVIRONMENT_IMPACT_POTENTIAL   int64
#  20  ENERGY_CONSUMPTION_CURRENT     int64
#  21  ENERGY_CONSUMPTION_POTENTIAL   float64
#  22  CO2_EMISSIONS_CURRENT          float64
#  23  CO2_EMISS_CURR_PER_FLOOR_AREA  int64
#  24  CO2_EMISSIONS_POTENTIAL        float64
#  25  LIGHTING_COST_CURRENT          float64
#  26  LIGHTING_COST_POTENTIAL        float64
#  27  HEATING_COST_CURRENT           float64
#  28  HEATING_COST_POTENTIAL         float64
#  29  HOT_WATER_COST_CURRENT         float64
#  30  HOT_WATER_COST_POTENTIAL       float64
#  31  TOTAL_FLOOR_AREA               float64
#  32  ENERGY_TARIFF                  object
#  33  MAINS_GAS_FLAG                 object
#  34  FLOOR_LEVEL                    object
#  35  FLAT_TOP_STOREY                object
#  36  FLAT_STOREY_COUNT              float64
#  37  MAIN_HEATING_CONTROLS          object
#  38  MULTI_GLAZE_PROPORTION         float64
#  39  GLAZED_TYPE                    object
#  40  GLAZED_AREA                    object
#  41  EXTENSION_COUNT                float64
#  42  NUMBER_HABITABLE_ROOMS         float64
#  43  NUMBER_HEATED_ROOMS            float64
#  44  LOW_ENERGY_LIGHTING            float64
#  45  NUMBER_OPEN_FIREPLACES         float64
#  46  HOTWATER_DESCRIPTION           object
#  47  HOT_WATER_ENERGY_EFF           object
#  48  HOT_WATER_ENV_EFF              object
#  49  FLOOR_DESCRIPTION              object
#  50  FLOOR_ENERGY_EFF               object
#  51  FLOOR_ENV_EFF                  object
#  52  WINDOWS_DESCRIPTION            object
#  53  WINDOWS_ENERGY_EFF             object
#  54  WINDOWS_ENV_EFF                object
#  55  WALLS_DESCRIPTION              object
#  56  WALLS_ENERGY_EFF               object
#  57  WALLS_ENV_EFF                  object
#  58  SECONDHEAT_DESCRIPTION         object
#  59  SHEATING_ENERGY_EFF            float64
#  60  SHEATING_ENV_EFF               float64
#  61  ROOF_DESCRIPTION               object
#  62  ROOF_ENERGY_EFF                object
#  63  ROOF_ENV_EFF                   object
#  64  MAINHEAT_DESCRIPTION           object
#  65  MAINHEAT_ENERGY_EFF            object
#  66  MAINHEAT_ENV_EFF               object
#  67  MAINHEATCONT_DESCRIPTION       object
#  68  MAINHEATC_ENERGY_EFF           object
#  69  MAINHEATC_ENV_EFF              object
#  70  LIGHTING_DESCRIPTION           object
#  71  LIGHTING_ENERGY_EFF            object
#  72  LIGHTING_ENV_EFF               object
#  73  MAIN_FUEL                      object
#  74  WIND_TURBINE_COUNT             float64
#  75  HEAT_LOSS_CORRIDOR             object
#  76  UNHEATED_CORRIDOR_LENGTH       float64
#  77  FLOOR_HEIGHT                   float64
#  78  PHOTO_SUPPLY                   float64
#  79  SOLAR_WATER_HEATING_FLAG       object
#  80  MECHANICAL_VENTILATION         object
#  81  ADDRESS                        object
#  82  LOCAL_AUTHORITY_LABEL          object
#  83  CONSTITUENCY_LABEL             object
#  84  POSTTOWN                       object
#  85  CONSTRUCTION_AGE_BAND          object
#  86  LODGEMENT_DATETIME             object
#  87  TENURE                         object
#  88  FIXED_LIGHTING_OUTLETS_COUNT   float64
#  89  LOW_ENERGY_FIXED_LIGHT_COUNT   float64
#  90  UPRN                           float64
#  91  UPRN_SOURCE                    object
#  92  REPORT_TYPE                    int64
# dtypes: float64(26), int64(8), object(59)
# memory usage: 2.3+ GB

# %%
"""
keep these fields:
POSTCODE
ADDRESS
CURRENT_ENERGY_RATING
TOTAL_FLOOR_AREA
ADDRESS1
ADDRESS2
ADDRESS3
LODGEMENT_DATE

Do we need to dedup? If so take the last date.
"""

# lowercase column names
epc_master.columns = [col.lower() for col in epc_master.columns]
# reduce to key fields and lowercase column names
epc_reduced = epc_master[[
    'postcode', 
    'address', 
    'current_energy_rating', 
    'total_floor_area', 
    'address1', 
    'address2', 
    'address3', 
    'lodgement_date']]

epc_reduced.head()
# Out:
#    postcode                                            address  \
# 0  DE22 2XJ                        1, Quarndon View, Allestree
# 1  DE23 8SR                                  69, Violet Street
# 2  DE23 1NG                   15, Charnwood Avenue, Littleover
# 3   DE1 3FF  PENTHOUSE 1, KINGS CRESCENT APARTMENTS, EDWARD...
# 4  DE23 1LD                      19, Stenson Avenue, Sunnyhill
#
#   current_energy_rating  total_floor_area              address1  \
# 0                     D            166.57      1, Quarndon View
# 1                     D             74.00     69, Violet Street
# 2                     D             88.00  15, Charnwood Avenue
# 3                     B            105.00           PENTHOUSE 1
# 4                     D             69.00    19, Stenson Avenue
#
#                     address2       address3 lodgement_date
# 0                  Allestree            NaN     2011-10-10
# 1                        NaN            NaN     2010-06-30
# 2                 Littleover            NaN     2015-12-16
# 3  KINGS CRESCENT APARTMENTS  EDWARD STREET     2021-07-08
# 4                  Sunnyhill            NaN     2014-05-16

# %%
epc_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3343753 entries, 0 to 3343752
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   postcode               object
#  1   address                object
#  2   current_energy_rating  object
#  3   total_floor_area       float64
#  4   address1               object
#  5   address2               object
#  6   address3               object
#  7   lodgement_date         object
# dtypes: float64(1), object(7)
# memory usage: 204.1+ MB

# %%
# any duplicates?
duplicates = epc_reduced.duplicated(subset=['postcode', 'address'], keep=False)
print(f"Number of duplicate entries based on postcode and address: {duplicates.sum()}")
# Out:
# Number of duplicate entries based on postcode and address: 1027297

# %%
# show duplicates
epc_reduced[duplicates].sort_values(by=['postcode', 'address']).head(10)
# Out:
#         postcode                                            address  \
# 2107984   B1 1BA  Apartment 2003 Beetham Tower, 10, Holloway Cir...
# 2349086   B1 1BA  Apartment 2003 Beetham Tower, 10, Holloway Cir...
# 2077857   B1 1BA      Apartment 2105, 10, Holloway Circus Queensway
# 2376708   B1 1BA      Apartment 2105, 10, Holloway Circus Queensway
# 2279905   B1 1BA      Apartment 2108, 10, Holloway Circus Queensway
# 2316681   B1 1BA      Apartment 2108, 10, Holloway Circus Queensway
# 2331876   B1 1BA      Apartment 2205, 10, Holloway Circus Queensway
# 2407818   B1 1BA      Apartment 2205, 10, Holloway Circus Queensway
# 2281363   B1 1BA      Apartment 2304, 10, Holloway Circus Queensway
# 2301849   B1 1BA      Apartment 2304, 10, Holloway Circus Queensway
#
#         current_energy_rating  total_floor_area                      address1  \
# 2107984                     C            40.000  Apartment 2003 Beetham Tower
# 2349086                     C            40.000  Apartment 2003 Beetham Tower
# 2077857                     B            73.250                Apartment 2105
# 2376708                     D            64.440                Apartment 2105
# 2279905                     C            78.000                Apartment 2108
# 2316681                     E           101.853                Apartment 2108
# 2331876                     C            60.000                Apartment 2205
# 2407818                     C            60.300                Apartment 2205
# 2281363                     C            73.000                Apartment 2304
# 2301849                     D            64.439                Apartment 2304
#
#                               address2 address3 lodgement_date
# 2107984  10, Holloway Circus Queensway      NaN     2020-06-15
# 2349086  10, Holloway Circus Queensway      NaN     2020-06-15
# 2077857  10, Holloway Circus Queensway      NaN     2011-10-07
# 2376708  10, Holloway Circus Queensway      NaN     2010-11-28
# 2279905  10, Holloway Circus Queensway      NaN     2018-08-26
# 2316681  10, Holloway Circus Queensway      NaN     2010-11-25
# 2331876  10, Holloway Circus Queensway      NaN     2019-01-21
# 2407818  10, Holloway Circus Queensway      NaN     2008-12-01
# 2281363  10, Holloway Circus Queensway      NaN     2018-08-26
# 2301849  10, Holloway Circus Queensway      NaN     2010-11-25

# %%
# deduplicate by postcode and address, keeping the most recent lodgement date
epc_reduced = epc_reduced.sort_values('lodgement_date').drop_duplicates(subset=['postcode', 'address'], keep='last')
epc_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2776742 entries, 2102727 to 2874689
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   postcode               object
#  1   address                object
#  2   current_energy_rating  object
#  3   total_floor_area       float64
#  4   address1               object
#  5   address2               object
#  6   address3               object
#  7   lodgement_date         object
# dtypes: float64(1), object(7)
# memory usage: 190.7+ MB

# %%
# drop address lines we don't need
epc_reduced = epc_reduced.drop(columns=['address1', 'address2', 'address3'])

# %%
# write out the reduced file
epc_reduced.to_csv("../data/clean/epc_master.csv", index=False)

# %%
# zip the cleaned file as it is over 100MB
with zipfile.ZipFile("../data/clean/epc_master.zip", 'w', zipfile.ZIP_DEFLATED) as zf:
    zf.write("../data/clean/epc_master.csv", arcname="epc_master.csv")

# %%
# remove the unzipped cleaned file to save space
Path("../data/clean/epc_master.csv").unlink()
